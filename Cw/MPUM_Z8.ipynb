# %% [markdown]
# # Zadanie 1
#
# Mając do dyspozycji dane Titanic, stwórz optymalny model objaśniająycy zmienną "survived".
#
# * dokonaj analizy danych tak by dało się nauczyć model
# * wykonaj podział na zbiór testowy i treningowy
# * znajdż optymalny model
#     * użyj walidacji krzyzowej
#     * sprawdź rózne modeli regresji logistycznej oraz SVM
# * wybierz miarę oceny (np F1 score) i wypisz wyniki przetestowanych metod

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('http://stamfordresearch.com/wp-content/uploads/2016/08/Titanic.csv') 
print(df.shape)
df.head()
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# # Zadanie 2
#
# Ściągnij bazę pisanych cyfr handwritten digits data i wyświetl kilka z nich.

# %%
from sklearn.datasets import load_digits
digits = load_digits()
print(digits.keys())
# Out:
# dict_keys(['data', 'target', 'target_names', 'images', 'DESCR'])

# %%
# Out:
# digits.keys() = dict_keys(['data', 'target', 'target_names', 'images', 'DESCR'])
# digits.images.shape = (1797, 8, 8)
# digits.data.shape = (1797, 64)
# digits.target.shape = (1797,)

# %% [markdown]
# # Zadanie 3
# Mając do dyspozycji dane handwritten digits, stwórz optymalny model predykcji.
#
# * wykonaj podział na zbiór testowy i treningowy
# * znajdż optymalny model
#     * użyj walidacji krzyzowej
#     * sprawdź rózne modele regresji logistycznej oraz SVM
# * wybierz miarę oceny (np F1 score) i wypisz wyniki przetestowanych medeli

# %% [markdown]
# # Zadanie 4
#
# Ściągnij bazę twarzy fetch_olivetti_faces i wyświetl kilka twarzy.

# %%
import sklearn as sk
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_olivetti_faces
faces = fetch_olivetti_faces()
# Out:
# downloading Olivetti faces from http://cs.nyu.edu/~roweis/data/olivettifaces.mat to C:\Users\przem85\scikit_learn_data

# %% [markdown]
# Looking at the content of the faces object, we get the following properties: images, data, and target. Images contain the 400 images represented as 64 x 64 pixel matrices. data contains the same 400 images but as array of 4096 pixels. target is, as expected, an array with the target classes, ranging from 0 to 39.

# %%
print(faces.keys())
print(faces.images.shape)
print(faces.data.shape)
print(faces.target.shape)
# Out:
# dict_keys(['data', 'images', 'target', 'DESCR'])
# (400, 64, 64)
# (400, 4096)
# (400,)

# %% [markdown]
# # Zadanie 5
# Mając do dyspozycji dane fetch_olivetti_faces, stwórz optymalny model predykcji.
#
# * wykonaj podział na zbiór testowy i treningowy
# * znajdż optymalny model
#     * użyj walidacji krzyzowej
#     * sprawdź rózne modele regresji logistycznej oraz SVM
# * wybierz miarę oceny (np F1 score) i wypisz wyniki przetestowanych medeli
