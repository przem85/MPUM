# %% [markdown]
# # Zadanie 1
#
# Za pomocą funkcji:
#
# ```python
# sklearn.datasets.make_moons
# ```
#
# wygeneruj 4 zbiory danych z parametrami:
#
#   * n_samples=1000, noise=.05
#   * n_samples=1000, noise=.3
#   * n_samples=200, noise=.05
#   * n_samples=200, noise=.3

# %% [markdown]
# # Zadanie 2
# Analogicznie jak w zestawie 4 predykcji można dokonać dla dowolnego punktu na płaszczyźnie. Wygeneruj punkty równomiernie na kwadracie zawierającym punkty i wykonaj dla nich predykcję.
#
# Oryginalny zbiór danych niech będzie pokolorowany za pomocą oryginalnych klas.
#
# Wykorzystaj Perceptron
# ```python
# sklearn.linear_model.Perceptron
# ```

# %%
from sklearn.linear_model import Perceptron

# %% [markdown]
# # Zadanie 3
# Analogicznie jak w zestawie 4 predykcji można dokonać dla dowolnego punktu na płaszczyźnie. Wygeneruj punkty równomiernie na kwadracie zawierającym punkty i wykonaj dla nich predykcję.
#
# Oryginalny zbiór danych niech będzie pokolorowany za pomocą oryginalnych klas.
#
# Wykonaj Multi-layer Perceptron classifier:
# ```python
# sklearn.neural_network.MLPClassifier
# ```
#
# Który z modeli jest najlepszy?

# %%
from sklearn.neural_network import MLPClassifier

# %%
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)

# %%
# MLPClassifier(hidden_layer_sizes=(100,100))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)

# %% [markdown]
# # Zadanie 4
# Dla danych iris (dwie wybrane współrzędne) wytrenuj Multi-layer Perceptron classifier dobierając optymalne parametry za pomocą cross-validation.

# %% [markdown]
# # Zadanie 5
# Mając do dyspozycji dane handwritten digits, stwórz optymalny model predykcji.
#
# * wykonaj podział na zbiór testowy i treningowy
# * znajdż optymalny model
#     * użyj walidacji krzyzowej
#     * sprawdź rózne modele
#       * regresji logistycznej
#       * SVM
#       * Perceptron
#       * MLPClassifier
# * wybierz miarę oceny (np F1 score) i wypisz wyniki przetestowanych medeli

# %% [markdown]
# # Zadanie 6
#
# Dla poniższych danych wykonaj regresję za pomocą SVM regression
# ```python
# SVR(kernel='rbf', C=1e3, gamma=0.1)
# ```

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
from sklearn import datasets, linear_model
import matplotlib.pyplot as plt

from sklearn.svm import SVR

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
#plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie 7
#
# Dla danych z powyższego zadania oras SVR znajdź najlepsze parametry za pomocą cross validation

# %% [markdown]
# # Zadanie 8
#
# Dla danych z powyższego zadania wykonaj regresję za pomocą Multi-layer Perceptron
# ```python
# MLPRegressor()
# ```

# %%
from sklearn.neural_network import MLPRegressor

# %% [markdown]
# # Zadanie 9
#
# Dla danych z powyższego zadania oras MLPRegressor znajdź najlepsze parametry za pomocą cross validation

# %% [markdown]
# # Zadanie 10
# Wykonajmy regresję:
#
# - klasyczną
# - regresję grzbietową (Ridge)
# - regresję Lasso
# - Elastic Net
# - MLPRegressor
# - SVR
#
# dobierając optymalne parametry za pomocą cross validation.
#
# Wypisz wyniki dla każdj z metod po wykonaniu podwijnej cross validation.

# %%
from sklearn import datasets
boston = datasets.load_boston()
# print description
#print(boston.DESCR)

# %%
# get the data
boston_X = boston.data
boston_Y = boston.target

# Split the data into training/testing sets
boston_X_train = boston_X[:-50]
boston_X_test = boston_X[-50:]
 
# Split the targets into training/testing sets
boston_y_train = boston_Y[:-50]
boston_y_test = boston_Y[-50:]
